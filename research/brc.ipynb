# %% [markdown]
# # BuildingResourcesClassifier

# %%
# %pip install pandas --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
from os import environ
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env")

hf_token = environ.get('HF_TOKEN')
hf_write_token = environ.get('HF_WRITE_TOKEN')
openchat_host = environ.get('OPENCHAT_HOST')

# %% [markdown]
# ## Синтетический датасет

# %%
ksr_clean = pd.read_csv("ksr_clean.csv.gz")
ksr_clean
# Out:
#                                    okpd2  \
# 0       23.65.12.190.01.1.01.01-0002-000
# 1       23.65.12.190.01.1.01.02-0011-000
# 2       23.65.12.111.01.1.01.04-1018-000
# 3       23.65.12.111.01.1.01.04-1022-000
# 4       23.65.12.111.01.1.01.04-1024-000
# ...                                  ...
# 109849     28.22.14.159.96.01.10-001-000
# 109850     28.92.50.000.96.01.15-001-000
# 109851     28.92.50.000.96.01.15-002-000
# 109852     27.90.31.110.96.01.17-001-000
# 109853     27.90.31.110.96.01.17-002-000
#
#                                                      name       unit
# 0       Детали фасонные коньковые к листам хризотилцем...  100 компл
# 1       Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2       Листы хризотилцементные волнистые, профиль 40/...         м2
# 3       Листы хризотилцементные волнистые, профиль 40/...         м2
# 4       Листы хризотилцементные волнистые, профиль 40/...         м2
# ...                                                   ...        ...
# 109849  Трубоукладчики для труб диаметром до 700 мм, г...         шт
# 109850  Тракторы на гусеничном ходу, мощность 128,7 кВ...         шт
# 109851  Тракторы на гусеничном ходу, мощность 59 кВт (...         шт
# 109852            Агрегаты для сварки полиэтиленовых труб         шт
# 109853  Агрегаты сварочные передвижные с дизельным дви...         шт
#
# [109854 rows x 3 columns]

# %%
ksr_clean["okpd2"] = ksr_clean["okpd2"].apply(lambda x: x.split("-")[0])
ksr_clean
# Out:
#                           okpd2  \
# 0       23.65.12.190.01.1.01.01
# 1       23.65.12.190.01.1.01.02
# 2       23.65.12.111.01.1.01.04
# 3       23.65.12.111.01.1.01.04
# 4       23.65.12.111.01.1.01.04
# ...                         ...
# 109849    28.22.14.159.96.01.10
# 109850    28.92.50.000.96.01.15
# 109851    28.92.50.000.96.01.15
# 109852    27.90.31.110.96.01.17
# 109853    27.90.31.110.96.01.17
#
#                                                      name       unit
# 0       Детали фасонные коньковые к листам хризотилцем...  100 компл
# 1       Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2       Листы хризотилцементные волнистые, профиль 40/...         м2
# 3       Листы хризотилцементные волнистые, профиль 40/...         м2
# 4       Листы хризотилцементные волнистые, профиль 40/...         м2
# ...                                                   ...        ...
# 109849  Трубоукладчики для труб диаметром до 700 мм, г...         шт
# 109850  Тракторы на гусеничном ходу, мощность 128,7 кВ...         шт
# 109851  Тракторы на гусеничном ходу, мощность 59 кВт (...         шт
# 109852            Агрегаты для сварки полиэтиленовых труб         шт
# 109853  Агрегаты сварочные передвижные с дизельным дви...         шт
#
# [109854 rows x 3 columns]

# %%
ksr_clean_unique = ksr_clean.drop_duplicates(subset="okpd2", ignore_index=True)
ksr_clean_unique
# Out:
#                         okpd2  \
# 0     23.65.12.190.01.1.01.01
# 1     23.65.12.190.01.1.01.02
# 2     23.65.12.111.01.1.01.04
# 3     23.65.12.122.01.1.01.05
# 4     23.65.12.121.01.1.01.05
# ...                       ...
# 4721    28.92.30.160.96.01.08
# 4722    30.20.12.110.96.01.09
# 4723    28.22.14.159.96.01.10
# 4724    28.92.50.000.96.01.15
# 4725    27.90.31.110.96.01.17
#
#                                                    name       unit
# 0     Детали фасонные коньковые к листам хризотилцем...  100 компл
# 1     Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2     Листы хризотилцементные волнистые, профиль 40/...         м2
# 3     Листы хризотилцементные плоские непрессованные...         м2
# 4     Листы хризотилцементные плоские прессованные, ...         м2
# ...                                                 ...        ...
# 4721  Укладчики асфальтобетона больших типоразмеров,...         шт
# 4722  Тепловозы широкой колеи, мощность до 552 кВт (...         шт
# 4723  Трубоукладчики для труб диаметром до 700 мм, г...         шт
# 4724  Тракторы на гусеничном ходу, мощность 128,7 кВ...         шт
# 4725            Агрегаты для сварки полиэтиленовых труб         шт
#
# [4726 rows x 3 columns]

# %%
import re

names = ksr_clean_unique["name"].apply(lambda x: re.sub(r"[^a-zA-Zа-яА-Я]+", " ", x))
names
# Out:
# 0       Детали фасонные коньковые к листам хризотилцем...
# 1       Доска электротехническая дугостойкая АЦЭИД тол...
# 2       Листы хризотилцементные волнистые профиль волн...
# 3       Листы хризотилцементные плоские непрессованные...
# 4       Листы хризотилцементные плоские прессованные т...
#                               ...
# 4721    Укладчики асфальтобетона больших типоразмеров ...
# 4722         Тепловозы широкой колеи мощность до кВт л с
# 4723    Трубоукладчики для труб диаметром до мм грузоп...
# 4724        Тракторы на гусеничном ходу мощность кВт л с
# 4725              Агрегаты для сварки полиэтиленовых труб
# Name: name, Length: 4726, dtype: object

# %%
from langchain.prompts import PromptTemplate

prompt_template = """
Действуйте, как инженер-строительь, пытающийся закупить у поставщика строительные ресурсы из некоторой группы и приводящий названия строительных материалов и машин от официального классификатора строительных ресурсов к магазинным.
Требуется перефразировать официальные названия в другие похожие, которые можно заказать в строительном магазине.

Например:
```
\"DIN-рейки металлические, оцинкованные, размеры мм\";\"DIN -рейка оцинкованная см (Chint)\"
\"Анкер грунтовый забивной самораскрывающийся, оцинкованный, предельная несущая нагрузка не менее кН\";\"Анкерный элемент ТехноНиколь мм\"
\"Анкер металлический канатный, диаметр грузонесущего стержня мм, предельная несущая нагрузка не менее кН, длина мм\";\"Анкерный стержень мм без покрытия м\"
\"Анкер химический двухкомпонентный на основе винилэстеровой смолы\";\"Химический Анкер на основе полиэстра мл Akfix C (шт в упк)\"
```

Сгенерируйте для следующих наименований перефразированные названия материалов или машин в формате CSV, при этом используйте наименования из строительного магазина, опечатки, аббревиатуры и ни в коем случае не повторяйтесь:
{content}

\"название группы\";\"название нужного тебе материала из этой группы\"
"""

prompt = PromptTemplate.from_template(prompt_template)

from langchain_openai import ChatOpenAI

openchat = ChatOpenAI(
    model="openchat_3.5",
    openai_api_key="EMPTY",
    openai_api_base=openchat_host,
    temperature=0.7,
)

openchat_chain = prompt | openchat

# %%
lines = []

# %%
for i in range(50, len(names), 50):
    lines += openchat_chain.invoke({"content": "\n".join(names[i-50:i])}).content.split("\n")
    print(i, "/", len(names))
# Out:
# 50 / 4726
# 100 / 4726
# 150 / 4726
# 200 / 4726
# 250 / 4726
# 300 / 4726
# 350 / 4726
# 400 / 4726
# 450 / 4726
# 500 / 4726
# 550 / 4726
# 600 / 4726
# 650 / 4726
# 700 / 4726
# 750 / 4726
# 800 / 4726
# 850 / 4726
# 900 / 4726
# 950 / 4726
# 1000 / 4726
# 1050 / 4726
# 1100 / 4726
# 1150 / 4726
# 1200 / 4726
# 1250 / 4726
# 1300 / 4726
# 1350 / 4726
# 1400 / 4726
# 1450 / 4726
# 1500 / 4726
# 1550 / 4726
# 1600 / 4726
# 1650 / 4726
# 1700 / 4726
# 1750 / 4726
# 1800 / 4726
# 1850 / 4726
# 1900 / 4726
# 1950 / 4726
# 2000 / 4726
# 2050 / 4726
# 2100 / 4726
# 2150 / 4726
# 2200 / 4726
# 2250 / 4726
# 2300 / 4726
# 2350 / 4726
# 2400 / 4726
# 2450 / 4726
# 2500 / 4726
# 2550 / 4726
# 2600 / 4726
# 2650 / 4726
# 2700 / 4726
# 2750 / 4726
# 2800 / 4726
# 2850 / 4726
# 2900 / 4726
# 2950 / 4726
# 3000 / 4726
# 3050 / 4726
# 3100 / 4726
# 3150 / 4726
# 3200 / 4726
# 3250 / 4726
# 3300 / 4726
# 3350 / 4726
# 3400 / 4726
# 3450 / 4726
# 3500 / 4726
# 3550 / 4726
# 3600 / 4726
# 3650 / 4726
# 3700 / 4726
# 3750 / 4726
# 3800 / 4726
# 3850 / 4726
# 3900 / 4726
# 3950 / 4726
# 4000 / 4726
# 4050 / 4726
# 4100 / 4726
# 4150 / 4726
# 4200 / 4726
# 4250 / 4726
# 4300 / 4726
# 4350 / 4726
# 4400 / 4726
# 4450 / 4726
# 4500 / 4726
# 4550 / 4726
# 4600 / 4726
# 4650 / 4726
# 4700 / 4726

# %%
lines

# %%
open("openchat_gen.csv", "w", encoding="utf-8").write("\n".join(lines))
# Out:
# 506169

# %% [markdown]
# ## Дообучение Sentence BERT

# %%
train_dataset = pd.read_csv("train.csv")
train_dataset.columns=["x", "y"]
train_dataset
# Out:
#                                                     x  \
# 0     DIN -рейка оцинкованная ТН35-7.5 100 см (Chint)
# 1                 Анкерный элемент ТехноНиколь 8*45мм
# 2                  Анкер забивной М10 DRM 12x40 сталь
# 3                            Анкер забивной М10/12x40
# 4                        Анкер забивной М8 LAZ латунь
# ...                                               ...
# 4809                      Межкомнатные двери 900х2000
# 4810                Кремнийорганическая эмаль КО-8104
# 4811                Кремнийорганическая эмаль КО-8104
# 4812                Кремнийорганическая эмаль КО-8104
# 4813                             Эмаль ПФ - 115 белая
#
#                                                       y
# 0     DIN-рейки металлические, оцинкованные, размеры...
# 1     Анкер грунтовый забивной самораскрывающийся, о...
# 2     Анкер забивной латунный, диаметр внутренней ре...
# 3     Анкер забивной латунный, диаметр внутренней ре...
# 4     Анкер забивной латунный, диаметр внутренней ре...
# ...                                                 ...
# 4809  Щит учетно-распределительный встраиваемый ЩУРВ...
# 4810  Эмаль кремнийорганическая термостойкая КО-811К...
# 4811       Эмаль кремнийорганическая термостойкая КО-88
# 4812       Эмаль кремнийорганическая термостойкая КО-88
# 4813                                 Эмаль ПФ-115 белая
#
# [4814 rows x 2 columns]

# %%
# %pip install scikit-learn --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(train_dataset, test_size=0.25, random_state=42)
X_train
# Out:
#                                                       x  \
# 1051                       Клапан КСП-2-НО-MB(220)-ф160
# 2758                              Гайка оц. DIN 934 М16
# 3080                         5х1,5 мм2 ВВГнг(А)-FRLSLTx
# 2370                  Шпилька резьбовая М12x2000 оцинк.
# 1330  Кран шаровой LD Цельносварной приварной Ду.32 ...
# ...                                                 ...
# 4426                           ДТ-Сорт-С- Евро К5 зимня
# 466     Дюбель с шестигранной головкой KD-10100 (TSX-S)
# 3092              Провод ПуГВ 4 «белый» ПуГВнг(A)-LSLTx
# 3772  50 Полипропиленовый шаровой кран  полнопроходн...
# 860   Кабель АВВГнг(А)-LS 5х6 ОК (N PE)  0.66кВ (м) ...
#
#                                                       y
# 1051  Клапан обратный мембранный, номинальный диамет...
# 2758  Гайки стальные шестигранные, диаметр резьбы М1...
# 3080               Кабель силовой гибкий КГнг 5х1,5-660
# 2370  Шпильки стальные оцинкованные резьбовые, диаме...
# 1330  Кран шаровой газовый стальной, приварной, полн...
# ...                                                 ...
# 4426                                  Топливо дизельное
# 466   Дюбели фасадные полимерные с шурупом из нержав...
# 3092  Кабель силовой гибкий с медными жилами КГ 1х2,...
# 3772  Кран шаровой полнопроходной из нержавеющей ста...
# 860   Кабель силовой гибкий с медными жилами КГН 5х6...
#
# [3610 rows x 2 columns]

# %%
opendata = pd.read_csv("openchat_gen.csv", sep=";").dropna()
opendata
# Out:
#                                                       x  \
# 0     Детали фасонные коньковые к листам хризотилцем...
# 1     Доска электротехническая дугостойкая АЦЭИД тол...
# 2     Листы хризотилцементные волнистые профиль волн...
# 3     Листы хризотилцементные плоские непрессованные...
# 4     Листы хризотилцементные плоские прессованные т...
# ...                                                 ...
# 3867  Железобетоноломы гидроклинья с гидравлическим ...
# 3868  Комплексы вакуумные для вибровакуумной обработ...
# 3869                    Машины для райберовки отверстий
# 3870  Машины пневматические при работе от передвижны...
# 3871  Пеногенераторы низкого давления производительн...
#
#                                                       y
# 0     Детали фасонные для листов хризотилцементных с...
# 1                        Доска электротехническая ACEID
# 2          Листы хризотилцементные с волнистым профилем
# 3        Листы хризотилцементные плоские непрессованные
# 4          Листы хризотилцементные плоские прессованные
# ...                                                 ...
# 3867  Железобетоноломы для разрушения бетонных конст...
# 3868           Комплексы вакуумные для обработки бетона
# 3869          Машины для райберовки отверстий в металле
# 3870  Машины пневматические для забивания и извлечен...
# 3871  Пеногенераторы низкого давления для производст...
#
# [3705 rows x 2 columns]

# %%
train_dataset = pd.concat([X_train, opendata])
train_dataset = train_dataset.dropna()
train_dataset
# Out:
#                                                       x  \
# 1051                       Клапан КСП-2-НО-MB(220)-ф160
# 2758                              Гайка оц. DIN 934 М16
# 3080                         5х1,5 мм2 ВВГнг(А)-FRLSLTx
# 2370                  Шпилька резьбовая М12x2000 оцинк.
# 1330  Кран шаровой LD Цельносварной приварной Ду.32 ...
# ...                                                 ...
# 3867  Железобетоноломы гидроклинья с гидравлическим ...
# 3868  Комплексы вакуумные для вибровакуумной обработ...
# 3869                    Машины для райберовки отверстий
# 3870  Машины пневматические при работе от передвижны...
# 3871  Пеногенераторы низкого давления производительн...
#
#                                                       y
# 1051  Клапан обратный мембранный, номинальный диамет...
# 2758  Гайки стальные шестигранные, диаметр резьбы М1...
# 3080               Кабель силовой гибкий КГнг 5х1,5-660
# 2370  Шпильки стальные оцинкованные резьбовые, диаме...
# 1330  Кран шаровой газовый стальной, приварной, полн...
# ...                                                 ...
# 3867  Железобетоноломы для разрушения бетонных конст...
# 3868           Комплексы вакуумные для обработки бетона
# 3869          Машины для райберовки отверстий в металле
# 3870  Машины пневматические для забивания и извлечен...
# 3871  Пеногенераторы низкого давления для производст...
#
# [7315 rows x 2 columns]

# %%
import math
from sentence_transformers import SentenceTransformer, InputExample, losses
from torch.utils.data import DataLoader

train_set = []
for index, row in train_dataset.iterrows():
    train_set.append(InputExample(texts=[row['x'], row['y']]))

finetuned_model = SentenceTransformer("multilingual-e5-large-amethyst", device="cuda")

train_dataloader = DataLoader(train_set, shuffle=True, batch_size=16)
train_loss = losses.MultipleNegativesRankingLoss(finetuned_model)
# train_loss = losses.MegaBatchMarginLoss(finetuned_model)

num_epochs = 5
warmup_steps = math.ceil(len(train_set) * num_epochs * 0.1)

finetuned_model.fit(train_objectives=[(train_dataloader, train_loss)],
                    epochs=num_epochs,
                    warmup_steps=warmup_steps,
                    output_path="multilingual-e5-large-amethyst-advanced")

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('multilingual-e5-large-amethyst-advanced', device="cuda")
model

# %%
ksr_clean['embedding'] = ksr_clean['name'].apply(model.encode)
ksr_clean

# %%
ksr_clean.to_pickle('ksr_embeddings_advanced.pkl')

# %% [markdown]
# ## Векторный индекс документов

# %% [markdown]
# ### Структура БД

# %%
from typing import Optional
from pgvector.sqlalchemy import Vector
from sqlalchemy import Text, create_engine, select, text
from sqlalchemy.orm import DeclarativeBase, Mapped, Session, mapped_column

engine = create_engine(f"postgresql://{environ.get('POSTGRES_USER')}:{environ.get('POSTGRES_PASSWORD')}@{environ.get('POSTGRES_HOST')}/{environ.get('POSTGRES_DB')}", echo=False)

# %%
class Base(DeclarativeBase):
    pass

class BuRe(Base):
    __tablename__ = "bure"
    id: Mapped[int] = mapped_column(primary_key=True)
    text: Mapped[str] = mapped_column(Text())
    embedding: Mapped[Optional[Vector]] = mapped_column(Vector(1024))

# %%
with Session(engine) as session:
    session.execute(text('CREATE EXTENSION IF NOT EXISTS vector'))
    session.execute(text('DROP TABLE bure'))
    session.commit()
Base.metadata.create_all(engine)

# %% [markdown]
# ### Выбор нужного фрагмента через векторный индекс

# %%
embeddings_df = pd.read_pickle("ksr_embeddings_advanced.pkl")
embeddings_df
# Out:
#                                    okpd2  \
# 0       23.65.12.190.01.1.01.01-0002-000
# 1       23.65.12.190.01.1.01.02-0011-000
# 2       23.65.12.111.01.1.01.04-1018-000
# 3       23.65.12.111.01.1.01.04-1022-000
# 4       23.65.12.111.01.1.01.04-1024-000
# ...                                  ...
# 109849     28.22.14.159.96.01.10-001-000
# 109850     28.92.50.000.96.01.15-001-000
# 109851     28.92.50.000.96.01.15-002-000
# 109852     27.90.31.110.96.01.17-001-000
# 109853     27.90.31.110.96.01.17-002-000
#
#                                                      name       unit  \
# 0       Детали фасонные коньковые к листам хризотилцем...  100 компл
# 1       Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2       Листы хризотилцементные волнистые, профиль 40/...         м2
# 3       Листы хризотилцементные волнистые, профиль 40/...         м2
# 4       Листы хризотилцементные волнистые, профиль 40/...         м2
# ...                                                   ...        ...
# 109849  Трубоукладчики для труб диаметром до 700 мм, г...         шт
# 109850  Тракторы на гусеничном ходу, мощность 128,7 кВ...         шт
# 109851  Тракторы на гусеничном ходу, мощность 59 кВт (...         шт
# 109852            Агрегаты для сварки полиэтиленовых труб         шт
# 109853  Агрегаты сварочные передвижные с дизельным дви...         шт
#
#                                                 embedding
# 0       [-0.010501368, 0.021471858, 0.0145885525, 0.00...
# 1       [0.013649848, 0.002459875, 0.017529622, -0.057...
# 2       [0.002323004, 0.052264214, 0.018503241, -0.010...
# 3       [0.0009953775, 0.053347524, 0.020072117, -0.00...
# 4       [0.0019991654, 0.051726382, 0.01980431, -0.008...
# ...                                                   ...
# 109849  [-0.045473617, -0.034029517, 0.06730358, 0.037...
# 109850  [-0.0022187794, 0.01922989, 0.028764915, 0.033...
# 109851  [-0.00988839, 0.016392412, 0.027038978, 0.0324...
# 109852  [0.01691022, -0.018498275, 0.0052387696, -0.04...
# 109853  [0.0010091487, -0.015068258, 0.062422216, 0.00...
#
# [109854 rows x 4 columns]

# %%
with Session(engine) as session:
    for row, document in embeddings_df.iterrows():
        doc = BuRe(
            text=document["name"],
            embedding=document["embedding"],
        )
        session.add(doc)
    session.commit()

# %%
from sentence_transformers import SentenceTransformer
finetuned_model = SentenceTransformer('saved_models/multilingual-e5-large-amethyst-advanced', device="cpu")
finetuned_model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: XLMRobertaModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
final_test = pd.read_csv("final_test.csv", index_col=0)
final_test
# Out:
#                                                       x  \
# 2211  ХОМУТ С ГАЙКОЙ И РЕЗИНОВЫМ ПРОФИЛЕМ (AS CELIK)...
# 670   Кабель СегментЛАН F/UTP Cat5e PVCLSнг(А)-LS 4х...
# 2263                      Шайба М10 плоская DIN125 цинк
# 2420                     Двери противопожарные 900х2100
# 999                           Воздушный клапан КВК 125Р
# ...                                                 ...
# 276          Выключатель 1ОП BOLLETO белый 7021 IN НОМЕ
# 2350  Гидроизоляционная шпонка АКВАСТОП® ХВН-120-04 ...
# 2377                          Анкерный элемент TN 8x4.5
# 1366  Лист 06.0x1500x6000 г/к ст.Зпс ГОСТ16523-97 ГО...
# 1159  Комплект заделки стыков КЗС (Т) для предизолир...
#
#                                                       y
# 2211  Хомут металлический оцинкованный с одним быстр...
# 670    Кабель сигнально-блокировочный СБЗПу 4х2х0,9-700
# 2263                              Шайба плоская круглая
# 2420  Блок дверной металлический противопожарный одн...
# 999   Клапан обратный для регулирования воздушных по...
# ...                                                 ...
# 276   Выключатели двухклавишные для открытой проводк...
# 2350  Шпонка гидроизоляционная эластичная из ПВХ, ко...
# 2377  Анкер грунтовый забивной самораскрывающийся, о...
# 1366  Лист стальной рифленый горячекатаный, марки ст...
# 1159  Комплект для изоляции сварного стыка стальных ...
#
# [822 rows x 2 columns]

# %%
def get_nearest_text(text):
    with Session(engine) as session:
        return session.scalars(select(BuRe)
                        .order_by(BuRe.embedding.cosine_distance(
                            finetuned_model.encode(text)
                            )).limit(1)).first().text

get_nearest_text("Комплект заделки стыков КЗС (Т) для предизолир...	")
# Out:
# 'Комплект для изоляции стыкового соединения (муфта, пенопакет, термоклей, дренажные и вварные пробки), тип КИС-110, длина 600 мм'

# %%
# %%timeit
get_nearest_text("Комплект для изоляции стыкового соединения (муфта, пенопакет, термоклей, дренажные и вварные пробки), тип КИС-110, длина 600 мм")
# Out:
# 1.33 s ± 42.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
final_test["y_pred"] = final_test["x"].apply(get_nearest_text)
final_test.head(5)
# Out:
#                                                       x  \
# 2211  ХОМУТ С ГАЙКОЙ И РЕЗИНОВЫМ ПРОФИЛЕМ (AS CELIK)...
# 670   Кабель СегментЛАН F/UTP Cat5e PVCLSнг(А)-LS 4х...
# 2263                      Шайба М10 плоская DIN125 цинк
# 2420                     Двери противопожарные 900х2100
# 999                           Воздушный клапан КВК 125Р
#
#                                                       y  \
# 2211  Хомут металлический оцинкованный с одним быстр...
# 670    Кабель сигнально-блокировочный СБЗПу 4х2х0,9-700
# 2263                              Шайба плоская круглая
# 2420  Блок дверной металлический противопожарный одн...
# 999   Клапан обратный для регулирования воздушных по...
#
#                                                  y_pred
# 2211  Хомут соединительный с резиновым уплотнителем,...
# 670      Кабель витая пара S/FTP 4х2х0,57, категория 6A
# 2263  Шайба стальная плоская круглая, тип СТО 24, ди...
# 2420  Блок дверной рентгенозащитный двупольный распа...
# 999   Клапан воздушный под ручной привод или электро...

# %%
sum(final_test["y"] == final_test["y_pred"]) / len(final_test), len(final_test)
# Out:
# (0.052311435523114354, 822)

# %%
finetuned_model.save_to_hub(repo_id="nizamovtimur/multilingual-e5-large-amethyst-advanced", token=hf_write_token)
# Out:
# The `save_to_hub` method is deprecated and will be removed in a future version of SentenceTransformers. Please use `push_to_hub` instead for future model uploads.
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# tokenizer.json: 100%|██████████| 17.1M/17.1M [00:03<00:00, 4.69MB/s]
# model.safetensors: 100%|██████████| 2.24G/2.24G [06:29<00:00, 5.75MB/s]
# Upload 2 LFS files: 100%|██████████| 2/2 [06:30<00:00, 195.34s/it]
# 'https://huggingface.co/nizamovtimur/multilingual-e5-large-amethyst-advanced/commit/e733bfe53b49bfd63ee19de059ea60d6fc5e8a3c'
